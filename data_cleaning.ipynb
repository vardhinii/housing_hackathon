# %%
import pandas as pd
from glob import glob

# %%
df1 = pd.read_csv("dataset/property_data/Koramangala.csv", sep='/', on_bad_lines='skip')
df1
# Out:
#                           property_id  type   activation_date  bathroom  \
# 0    ff8080814780f308014797c79000082e  BHK2  06-03-2017,21:30         1
# 1    ff80808148f81af60148f88b69c60062  BHK3  28-03-2017,11:17         2
# 2    ff80808149393cef014960f1e0fb16d4   RK1  04-03-2017,14:33         1
# 3    ff808081499ce9550149a2bab4960434  BHK1  23-02-2017,10:49         1
# 4    ff8081814cf0d662014cf56a76181373   RK1  07-02-2017,12:29         1
# ..                                ...   ...               ...       ...
# 228  ff8081815b15c304015b1d81227b33f9  BHK4  30-03-2017,11:02         4
# 229  ff8081815b15c304015b1dcc0bd954d7  BHK2  30-03-2017,12:03         2
# 230  ff8081815b1fc86b015b1fed15ab05ad  BHK3  30-03-2017,22:08         3
# 231  ff8081815b1fdda8015b1fe675ae0146  BHK2  30-03-2017,21:42         1
# 232  ff8081815b200540015b20158b0103c9  BHK2  30-03-2017,22:30         1
#
#      floor  total_floor      furnishing  gym   latitude  longitude  ... lift  \
# ...

# %%
df1.to_csv("dataset/property_data/Koramangala.csv", index=False)

# %%
import chardet

with open('HSR_Layout.csv', 'rb') as file:
    raw_data = file.read()
    result = chardet.detect(raw_data)
    print(result)

# %%
df2 = pd.read_csv("dataset/property_data/HSR_Layout.csv", delimiter='/', encoding='UTF-32', on_bad_lines='skip')
df2
# Out:
#                           property_id  type   activation_date  bathroom  \
# 0    ff808081486e6af00148744180fd02b1  BHK2  19-02-2017 10:35         2
# 1    ff80808149393cef014955efe1500fd1  BHK2  25-03-2017 10:24         2
# 2    ff8080814ada14f3014b0bd49e7731ee  BHK2  07-02-2017 12:15         2
# 3    ff8081814bd62607014bde7f7bfa0d80   RK1  01-02-2017 23:45         1
# 4    ff8081814c17ede2014c211e32c51355  BHK1  28-03-2017 13:57         1
# ..                                ...   ...               ...       ...
# 425  ff8081815b106986015b14e6d29703dc  BHK2  28-03-2017 19:08         2
# 426  ff8081815b106c7d015b15d12a4039c9  BHK2  29-03-2017 11:43         2
# 427  ff8081815b15c304015b18bae9780193  BHK3  29-03-2017 12:17         2
# 428  ff8081815b1e90e8015b1ea2f9c60894  BHK1  30-03-2017 15:34         1
# 429  ff8081815b1ebf9e015b1f4060cc36b7  BHK1  30-03-2017 18:23         1
#
#      floor  total_floor      furnishing  gym   latitude  longitude  ... lift  \
# ...

# %%
df2.to_csv("dataset/property_data/HSR_Layout.csv", encoding='utf-8',index=False)

# %%
files = glob("dataset/property_data/*.csv")

df = pd.concat((pd.read_csv(file) for file in files), ignore_index=True)
df.head()
# Out:
#                         property_id  type   activation_date  bathroom  floor  \
# 0  ff8081814bd62607014be805dfed1f43  BHK2  25-03-2017 16:02         2      2
# 1  ff8081814c58efc3014c64d26b5a22c0  BHK2  05-03-2017 16:19         2      0
# 2  ff8081814cb771fb014cc5fc3ae52ae8  BHK2  09-03-2017 11:10         2      2
# 3  ff8081814d1e1f05014d1e6fc29402ee  BHK2  11-02-2017 17:42         2      0
# 4  ff8081814d42cfff014d46f6bef50f23  BHK2  21-03-2017 10:36         2      4
#
#    total_floor      furnishing gym   latitude  longitude  ...      location  \
# 0          2.0  SEMI_FURNISHED   0  12.903119  77.625072  ...  Bommanahalli
# 1          3.0   NOT_FURNISHED   0  12.906969  77.634841  ...  Bommanahalli
# 2          4.0  SEMI_FURNISHED   0  12.901993  77.634014  ...  Bommanahalli
# 3          1.0  SEMI_FURNISHED   1  12.900841  77.617877  ...  Bommanahalli
# 4          5.0  SEMI_FURNISHED   0  12.909926  77.622097  ...  Bommanahalli
#
# ...

# %%
df['location'] = df['location'].fillna('') + ' ' + df['locality'].fillna('')
# Out:
#                             property_id  type   activation_date  bathroom  \
# 0      ff8081814bd62607014be805dfed1f43  BHK2  25-03-2017 16:02         2
# 1      ff8081814c58efc3014c64d26b5a22c0  BHK2  05-03-2017 16:19         2
# 2      ff8081814cb771fb014cc5fc3ae52ae8  BHK2  09-03-2017 11:10         2
# 3      ff8081814d1e1f05014d1e6fc29402ee  BHK2  11-02-2017 17:42         2
# 4      ff8081814d42cfff014d46f6bef50f23  BHK2  21-03-2017 10:36         2
# ...                                 ...   ...               ...       ...
# 14093  ff8081815b106986015b14e6d29703dc  BHK2  28-03-2017 19:08         2
# 14094  ff8081815b106c7d015b15d12a4039c9  BHK2  29-03-2017 11:43         2
# 14095  ff8081815b15c304015b18bae9780193  BHK3  29-03-2017 12:17         2
# 14096  ff8081815b1e90e8015b1ea2f9c60894  BHK1  30-03-2017 15:34         1
# 14097  ff8081815b1ebf9e015b1f4060cc36b7  BHK1  30-03-2017 18:23         1
#
#        floor  total_floor      furnishing gym   latitude  longitude  ...  \
# ...

# %%
df.drop(['locality'], axis=1, inplace=True)
df
# Out:
#                             property_id  type   activation_date  bathroom  \
# 0      ff8081814bd62607014be805dfed1f43  BHK2  25-03-2017 16:02         2
# 1      ff8081814c58efc3014c64d26b5a22c0  BHK2  05-03-2017 16:19         2
# 2      ff8081814cb771fb014cc5fc3ae52ae8  BHK2  09-03-2017 11:10         2
# 3      ff8081814d1e1f05014d1e6fc29402ee  BHK2  11-02-2017 17:42         2
# 4      ff8081814d42cfff014d46f6bef50f23  BHK2  21-03-2017 10:36         2
# ...                                 ...   ...               ...       ...
# 14093  ff8081815b106986015b14e6d29703dc  BHK2  28-03-2017 19:08         2
# 14094  ff8081815b106c7d015b15d12a4039c9  BHK2  29-03-2017 11:43         2
# 14095  ff8081815b15c304015b18bae9780193  BHK3  29-03-2017 12:17         2
# 14096  ff8081815b1e90e8015b1ea2f9c60894  BHK1  30-03-2017 15:34         1
# 14097  ff8081815b1ebf9e015b1f4060cc36b7  BHK1  30-03-2017 18:23         1
#
#        floor  total_floor      furnishing gym   latitude  longitude  ... lift  \
# ...

# %%
df.to_csv("dataset/property_data.csv", index=False)
